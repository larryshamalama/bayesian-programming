# %%
import cython
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pymc3 as pm
import pandas as pd

import arviz as az

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
K = 4
n = 1000
mu_0 = [-5, 1, 7, 14]
sigma_0 = [1.5, 0.5, 2.5, 3]

pi = [0.20, 0.25, 0.20, 0.35]

# %%
x = []
cluster = []

for _ in range(n):
    x_cluster = np.random.choice([0, 1, 2, 3], size=[1,], p=pi)[0]
    x.append(np.random.normal(loc=mu_0[x_cluster], scale=sigma_0[x_cluster], size=[1,]).tolist()[0])
    cluster.append(x_cluster)
    
x = np.array(x)

# %%
fig = plt.figure(figsize=(6, 5))
sns.kdeplot(x, shade=True)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### Can have all components together

# %%
with pm.Model() as model:
    p = pm.Dirichlet("p", a=np.tile(1, K))
    
    sigma = pm.InverseGamma("sigma", alpha=2, beta=4, shape=(4,))
    mean  = pm.Normal("mean", mu=5, sigma=15, shape=(4,))
    
    y = pm.Mixture("y", 
                   w=p, 
                   comp_dists=pm.Normal.dist(mu=mean, sigma=sigma, shape=(4,)), 
                   observed=x)

    trace = pm.sample(draws=2000, 
                      chains=1, 
                      tune=500)
# Out:
# /Users/larryshamalama/opt/anaconda3/envs/stat/lib/python3.8/site-packages/pymc3/sampling.py:465: FutureWarning: In an upcoming release, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   warnings.warn(
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [mean, sigma, p]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2500' class='' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2500/2500 00:23<00:00 Sampling chain 0, 0 divergences]
#     </div>
# /Users/larryshamalama/opt/anaconda3/envs/stat/lib/python3.8/site-packages/pymc3/math.py:246: RuntimeWarning: divide by zero encountered in log1p
#   return np.where(x < 0.6931471805599453, np.log(-np.expm1(-x)), np.log1p(-np.exp(-x)))
# Sampling 1 chain for 500 tune and 2_000 draw iterations (500 + 2_000 draws total) took 23 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
trace.get_values("mean").shape
# Out:
# (2000, 4)

# %%
_ = az.plot_trace(trace)
# Out:
# /Users/larryshamalama/opt/anaconda3/envs/stat/lib/python3.8/site-packages/arviz/data/io_pymc3.py:96: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(

# %% [markdown]
# ### Having each component defined separately

# %%
with pm.Model() as model:
    p = pm.Dirichlet("p", a=np.tile(1, K))
    
    sigma = {}
    mean  = {}
    
    for dist in range(K):
        sigma[dist] = pm.InverseGamma(f"sigma_{dist}", alpha=2, beta=4, shape=(1,))
        mean[dist]  = pm.Normal(f"mean_{dist}", mu=5, sigma=15, shape=(1,))
    
    
    y = pm.Mixture("y", 
                   w=p, 
                   comp_dists=[pm.Normal.dist(mu=mean[dist], sigma=sigma[dist]) for dist in range(K)], 
                   observed=x)

    trace = pm.sample(draws=10000, 
                      chains=1, 
                      tune=2000)
# Out:
# /Users/larryshamalama/opt/anaconda3/envs/stat/lib/python3.8/site-packages/pymc3/sampling.py:465: FutureWarning: In an upcoming release, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   warnings.warn(
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [mean_3, sigma_3, mean_2, sigma_2, mean_1, sigma_1, mean_0, sigma_0, p]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 02:52<00:00 Sampling chain 0, 0 divergences]
#     </div>
# /Users/larryshamalama/opt/anaconda3/envs/stat/lib/python3.8/site-packages/pymc3/math.py:246: RuntimeWarning: divide by zero encountered in log1p
#   return np.where(x < 0.6931471805599453, np.log(-np.expm1(-x)), np.log1p(-np.exp(-x)))
# Sampling 1 chain for 2_000 tune and 10_000 draw iterations (2_000 + 10_000 draws total) took 172 seconds.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
_ = az.plot_trace(trace)
# Out:
# /Users/larryshamalama/opt/anaconda3/envs/stat/lib/python3.8/site-packages/arviz/data/io_pymc3.py:96: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(

# %%
# %load_ext watermark
# %watermark -n -u -v -iv -w
# Out:
# Last updated: Sat Apr 03 2021
#
# Python implementation: CPython
# Python version       : 3.8.5
# IPython version      : 7.19.0
#
# cython    : 0.29.22
# numpy     : 1.19.2
# pandas    : 1.1.5
# pymc3     : 3.11.0
# matplotlib: 3.3.2
# seaborn   : 0.11.1
#
# Watermark: 2.2.0
